# %%
import pandas as pd
csv = pd.read_csv("https://raw.githubusercontent.com/socratica/data/master/earthquake.csv")
csv.head(50)
# Out:
#     earthquake_id          occurred_on  latitude  longitude  depth  magnitude  \
# 0               1   1969-01-01 9:07:06    51.096   -179.392   45.0        5.6
# 1               2  1969-01-02 17:50:48   -56.096    -27.842   80.1        6.0
# 2               3   1969-01-03 3:16:40    37.140     57.899   10.0        5.5
# 3               4  1969-01-03 13:28:12    51.132   -179.306   15.0        5.9
# 4               5  1969-01-04 22:36:48    -6.850    129.821  105.0        5.8
# 5               6  1969-01-05 13:26:43    -7.970    158.888   60.0        7.0
# 6               7  1969-01-06 15:39:00   -10.407    164.479   10.0        6.9
# 7               8  1969-01-08 21:55:51    11.823    143.419   45.0        5.6
# 8               9   1969-01-10 3:20:55    28.920    130.667   25.0        5.9
# 9              10   1969-01-13 8:55:05    -7.967    158.999   50.0        5.8
# 10             11  1969-01-14 23:12:08    36.043     29.221   25.0        6.4
# ...

# %%
csv.describe()
# Out:
#        earthquake_id      latitude     longitude         depth     magnitude
# count   23119.000000  23119.000000  23119.000000  23119.000000  23119.000000
# mean    11560.000000      0.996424     38.423416     71.165256      5.874432
# std      6674.024773     30.012563    125.725951    124.327891      0.421113
# min         1.000000    -77.080000   -179.997000     -1.100000      5.500000
# 25%      5780.500000    -19.218500    -77.293500     12.950000      5.600000
# 50%     11560.000000     -4.054000    102.369000     33.000000      5.700000
# 75%     17339.500000     24.147000    144.795500     53.890000      6.000000
# max     23119.000000     86.922900    179.998000    700.000000      9.100000

# %%
csv.to_csv("earthquack.csv", index = False)

# %%
csv.head()
# Out:
#    earthquake_id          occurred_on  latitude  longitude  depth  magnitude  \
# 0              1   1969-01-01 9:07:06    51.096   -179.392   45.0        5.6
# 1              2  1969-01-02 17:50:48   -56.096    -27.842   80.1        6.0
# 2              3   1969-01-03 3:16:40    37.140     57.899   10.0        5.5
# 3              4  1969-01-03 13:28:12    51.132   -179.306   15.0        5.9
# 4              5  1969-01-04 22:36:48    -6.850    129.821  105.0        5.8
#
#   calculation_method       network_id  \
# 0                 mw     iscgem812771
# 1                 mw  iscgemsup812819
# 2                 mw     iscgem812826
# 3                 mw     iscgem812841
# 4                 mw     iscgem812879
#
#                                          place       cause
# 0  Andreanof Islands, Aleutian Islands, Alaska  earthquake
# 1                South Sandwich Islands region  earthquake
# 2              Turkmenistan-Iran border region  earthquake
# ...

# %%
csv.head(60)
# Out:
#     earthquake_id          occurred_on  latitude  longitude  depth  magnitude  \
# 0               1   1969-01-01 9:07:06    51.096   -179.392   45.0        5.6
# 1               2  1969-01-02 17:50:48   -56.096    -27.842   80.1        6.0
# 2               3   1969-01-03 3:16:40    37.140     57.899   10.0        5.5
# 3               4  1969-01-03 13:28:12    51.132   -179.306   15.0        5.9
# 4               5  1969-01-04 22:36:48    -6.850    129.821  105.0        5.8
# 5               6  1969-01-05 13:26:43    -7.970    158.888   60.0        7.0
# 6               7  1969-01-06 15:39:00   -10.407    164.479   10.0        6.9
# 7               8  1969-01-08 21:55:51    11.823    143.419   45.0        5.6
# 8               9   1969-01-10 3:20:55    28.920    130.667   25.0        5.9
# 9              10   1969-01-13 8:55:05    -7.967    158.999   50.0        5.8
# 10             11  1969-01-14 23:12:08    36.043     29.221   25.0        6.4
# ...
