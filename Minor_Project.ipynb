# %%
import pandas as pd

# %%
data = pd.read_csv("appstore_games (2).csv")

# %%
data
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595   284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...   285755462
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# ...                                                  ...         ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  1474626442
# 17003  https://apps.apple.com/us/app/eachother/id1474...  1474919257
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  1474962324
# 17005  https://apps.apple.com/us/app/fatall/id1474963671  1474963671
# 17006  https://apps.apple.com/us/app/the-three-kingdo...  1475076711
#
#                             Name                        Subtitle  \
# 0                         Sudoku                             NaN
# 1                        Reversi                             NaN
# 2                        Morocco                             NaN
# 3                  Sudoku (Free)                             NaN
# 4                   Senet Deluxe                             NaN
# ...                          ...                             ...
# 17002  Stack Puzzle : Rise Tower  Blast the cubes, solve puzzle!
# 17003                  EachOther                             NaN
# 17004         Rabbit Vs Tortoise                             NaN
# 17005                     FaTaLL                Most fun game!!!
# 17006   The Three Kingdoms :Bomb                             NaN
#
#                                                 Icon URL  Average User Rating  \
# 0      https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 1      https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 2      https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 3      https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 4      https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# ...                                                  ...                  ...
# 17002  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 17003  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 17004  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 17005  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 17006  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
#
#        User Rating Count  Price   In-app Purchases  \
# 0                 3553.0   2.99                NaN
# 1                  284.0   1.99                NaN
# 2                 8376.0   0.00                NaN
# 3               190394.0   0.00                NaN
# 4                   28.0   2.99                NaN
# ...                  ...    ...                ...
# 17002                NaN   0.00                NaN
# 17003                NaN   0.00                NaN
# 17004                NaN   0.00                NaN
# 17005                NaN   0.00  9.99, 49.99, 3.99
# 17006                NaN   0.00                NaN
#
#                                              Description  \
# 0      Join over 21,000,000 of our fans and download ...
# 1      The classic game of Reversi, also known as Oth...
# 2      Play the classic strategy game Othello (also k...
# 3      Top 100 free app for over a year.\nRated "Best...
# 4      "Senet Deluxe - The Ancient Game of Life and A...
# ...                                                  ...
# 17002  The goal is very simple, move the square horiz...
# 17003  Collect a score while you play!!\n\nBy linking...
# 17004  "Rabbit Vs Tortoise is chess type cool simple ...
# 17005  Upgrade your character and use your skills to ...
# 17006  The protagonist uses the method of placing a b...
#
#                       Developer Age Rating  \
# 0      Mighty Mighty Good Games         4+
# 1              Kiss The Machine         4+
# 2                   Bayou Games         4+
# 3      Mighty Mighty Good Games         4+
# 4               RoGame Software         4+
# ...                         ...        ...
# 17002               Zhigang Pei         4+
# 17003             Sultan Shindi         4+
# 17004             Vishal Baldha         4+
# 17005              Tayrem Games         4+
# 17006              ming bo tang         4+
#
#                                                Languages         Size  \
# 0      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   15853568.0
# 1                                                     EN   12328960.0
# 2                                                     EN     674816.0
# 3      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   21552128.0
# 4      DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...   34689024.0
# ...                                                  ...          ...
# 17002                                                 EN   64795648.0
# 17003                                                 EN  110341120.0
# 17004                                                 EN   23207936.0
# 17005                                                 EN  196750336.0
# 17006                                             EN, ZH   22952960.0
#
#       Primary Genre                                  Genres  \
# 0             Games                 Games, Strategy, Puzzle
# 1             Games                  Games, Strategy, Board
# 2             Games                  Games, Board, Strategy
# 3             Games                 Games, Strategy, Puzzle
# 4             Games       Games, Strategy, Board, Education
# ...             ...                                     ...
# 17002         Games  Games, Entertainment, Casual, Strategy
# 17003         Games                 Games, Family, Strategy
# 17004         Games                         Games, Strategy
# 17005         Games                 Games, Strategy, Action
# 17006         Games                 Games, Strategy, Puzzle
#
#       Original Release Date Current Version Release Date
# 0                11/07/2008                   30/05/2017
# 1                11/07/2008                   17/05/2018
# 2                11/07/2008                    5/09/2017
# 3                23/07/2008                   30/05/2017
# 4                18/07/2008                   22/07/2018
# ...                     ...                          ...
# 17002            30/07/2019                   30/07/2019
# 17003             1/08/2019                    1/08/2019
# 17004             3/08/2019                    3/08/2019
# 17005             1/08/2019                    1/08/2019
# 17006             2/08/2019                    2/08/2019
#
# [17007 rows x 18 columns]

# %%
data.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# URL                                 0
# ID                                  0
# Name                                0
# Subtitle                        11746
# Icon URL                            0
# Average User Rating              9446
# User Rating Count                9446
# Price                              24
# In-app Purchases                 9324
# Description                         0
# Developer                           0
# Age Rating                          0
# Languages                          60
# Size                                1
# Primary Genre                       0
# Genres                              0
# Original Release Date               0
# Current Version Release Date        0
# dtype: int64

# %%
data.shape
# Out:
# (17007, 18)

# %%
data.dropna(subset = ["Average User Rating"])
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595   284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...   285755462
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# ...                                                  ...         ...
# 16950  https://apps.apple.com/us/app/die-last/id14730...  1473084135
# 16956  https://apps.apple.com/us/app/basic-slosh/id14...  1473181500
# 16962  https://apps.apple.com/us/app/idle-racing-tyco...  1473559573
# 16967  https://apps.apple.com/us/app/glow-hockey-stri...  1473680543
# 16993  https://apps.apple.com/us/app/agadmator-chess-...  1474461379
#
#                         Name                       Subtitle  \
# 0                     Sudoku                            NaN
# 1                    Reversi                            NaN
# 2                    Morocco                            NaN
# 3              Sudoku (Free)                            NaN
# 4               Senet Deluxe                            NaN
# ...                      ...                            ...
# 16950               Die Last                Who can survive
# 16956            Basic Slosh                            NaN
# 16962     Idle Racing Tycoon    Develop Your Car Racing Inc
# 16967     Glow Hockey Strike  Best 2 player air hockey game
# 16993  Agadmator Chess Clock   Simple & elegant chess clock
#
#                                                 Icon URL  Average User Rating  \
# 0      https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 1      https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 2      https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 3      https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 4      https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# ...                                                  ...                  ...
# 16950  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 16956  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16962  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16967  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16993  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
#
#        User Rating Count  Price In-app Purchases  \
# 0                 3553.0   2.99              NaN
# 1                  284.0   1.99              NaN
# 2                 8376.0   0.00              NaN
# 3               190394.0   0.00              NaN
# 4                   28.0   2.99              NaN
# ...                  ...    ...              ...
# 16950                6.0   0.00              NaN
# 16956               30.0   0.00              NaN
# 16962               51.0   0.00              NaN
# 16967                5.0   0.00              NaN
# 16993               33.0   0.00              NaN
#
#                                              Description  \
# 0      Join over 21,000,000 of our fans and download ...
# 1      The classic game of Reversi, also known as Oth...
# 2      Play the classic strategy game Othello (also k...
# 3      Top 100 free app for over a year.\nRated "Best...
# 4      "Senet Deluxe - The Ancient Game of Life and A...
# ...                                                  ...
# 16950  "Welcome to this mysterious room full of gears...
# 16956  "Take the ball to safety and reach the next le...
# 16962  Build your racing circuit.\n\nRecruit visitors...
# 16967  Glow Hockey Strike is a cool colorful air hock...
# 16993  Agadmator Chess Clock is a beautiful, lightwei...
#
#                       Developer Age Rating  \
# 0      Mighty Mighty Good Games         4+
# 1              Kiss The Machine         4+
# 2                   Bayou Games         4+
# 3      Mighty Mighty Good Games         4+
# 4               RoGame Software         4+
# ...                         ...        ...
# 16950                  Jie Yang        12+
# 16956          Ashnell Marchand         4+
# 16962              Carson Brody         9+
# 16967              Samir Jabeur         4+
# 16993              Ivan Amidzic         4+
#
#                                                Languages         Size  \
# 0      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   15853568.0
# 1                                                     EN   12328960.0
# 2                                                     EN     674816.0
# 3      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   21552128.0
# 4      DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...   34689024.0
# ...                                                  ...          ...
# 16950                                             EN, ZH  151308288.0
# 16956                                                 EN   79646720.0
# 16962                                                 EN  125348864.0
# 16967                                                 EN  128687104.0
# 16993                                                 EN    8845312.0
#
#       Primary Genre                                  Genres  \
# 0             Games                 Games, Strategy, Puzzle
# 1             Games                  Games, Strategy, Board
# 2             Games                  Games, Board, Strategy
# 3             Games                 Games, Strategy, Puzzle
# 4             Games       Games, Strategy, Board, Education
# ...             ...                                     ...
# 16950         Games  Games, Strategy, Entertainment, Puzzle
# 16956         Games  Games, Entertainment, Action, Strategy
# 16962         Games             Games, Simulation, Strategy
# 16967         Games             Games, Simulation, Strategy
# 16993         Games       Games, Strategy, Board, Utilities
#
#       Original Release Date Current Version Release Date
# 0                11/07/2008                   30/05/2017
# 1                11/07/2008                   17/05/2018
# 2                11/07/2008                    5/09/2017
# 3                23/07/2008                   30/05/2017
# 4                18/07/2008                   22/07/2018
# ...                     ...                          ...
# 16950            31/07/2019                   31/07/2019
# 16956            23/07/2019                   23/07/2019
# 16962            31/07/2019                   31/07/2019
# 16967            28/07/2019                   28/07/2019
# 16993            30/07/2019                   30/07/2019
#
# [7561 rows x 18 columns]

# %%
data.dropna(subset = ["User Rating Count"])
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595   284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...   285755462
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# ...                                                  ...         ...
# 16950  https://apps.apple.com/us/app/die-last/id14730...  1473084135
# 16956  https://apps.apple.com/us/app/basic-slosh/id14...  1473181500
# 16962  https://apps.apple.com/us/app/idle-racing-tyco...  1473559573
# 16967  https://apps.apple.com/us/app/glow-hockey-stri...  1473680543
# 16993  https://apps.apple.com/us/app/agadmator-chess-...  1474461379
#
#                         Name                       Subtitle  \
# 0                     Sudoku                            NaN
# 1                    Reversi                            NaN
# 2                    Morocco                            NaN
# 3              Sudoku (Free)                            NaN
# 4               Senet Deluxe                            NaN
# ...                      ...                            ...
# 16950               Die Last                Who can survive
# 16956            Basic Slosh                            NaN
# 16962     Idle Racing Tycoon    Develop Your Car Racing Inc
# 16967     Glow Hockey Strike  Best 2 player air hockey game
# 16993  Agadmator Chess Clock   Simple & elegant chess clock
#
#                                                 Icon URL  Average User Rating  \
# 0      https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 1      https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 2      https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 3      https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 4      https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# ...                                                  ...                  ...
# 16950  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 16956  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16962  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16967  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16993  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
#
#        User Rating Count  Price In-app Purchases  \
# 0                 3553.0   2.99              NaN
# 1                  284.0   1.99              NaN
# 2                 8376.0   0.00              NaN
# 3               190394.0   0.00              NaN
# 4                   28.0   2.99              NaN
# ...                  ...    ...              ...
# 16950                6.0   0.00              NaN
# 16956               30.0   0.00              NaN
# 16962               51.0   0.00              NaN
# 16967                5.0   0.00              NaN
# 16993               33.0   0.00              NaN
#
#                                              Description  \
# 0      Join over 21,000,000 of our fans and download ...
# 1      The classic game of Reversi, also known as Oth...
# 2      Play the classic strategy game Othello (also k...
# 3      Top 100 free app for over a year.\nRated "Best...
# 4      "Senet Deluxe - The Ancient Game of Life and A...
# ...                                                  ...
# 16950  "Welcome to this mysterious room full of gears...
# 16956  "Take the ball to safety and reach the next le...
# 16962  Build your racing circuit.\n\nRecruit visitors...
# 16967  Glow Hockey Strike is a cool colorful air hock...
# 16993  Agadmator Chess Clock is a beautiful, lightwei...
#
#                       Developer Age Rating  \
# 0      Mighty Mighty Good Games         4+
# 1              Kiss The Machine         4+
# 2                   Bayou Games         4+
# 3      Mighty Mighty Good Games         4+
# 4               RoGame Software         4+
# ...                         ...        ...
# 16950                  Jie Yang        12+
# 16956          Ashnell Marchand         4+
# 16962              Carson Brody         9+
# 16967              Samir Jabeur         4+
# 16993              Ivan Amidzic         4+
#
#                                                Languages         Size  \
# 0      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   15853568.0
# 1                                                     EN   12328960.0
# 2                                                     EN     674816.0
# 3      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   21552128.0
# 4      DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...   34689024.0
# ...                                                  ...          ...
# 16950                                             EN, ZH  151308288.0
# 16956                                                 EN   79646720.0
# 16962                                                 EN  125348864.0
# 16967                                                 EN  128687104.0
# 16993                                                 EN    8845312.0
#
#       Primary Genre                                  Genres  \
# 0             Games                 Games, Strategy, Puzzle
# 1             Games                  Games, Strategy, Board
# 2             Games                  Games, Board, Strategy
# 3             Games                 Games, Strategy, Puzzle
# 4             Games       Games, Strategy, Board, Education
# ...             ...                                     ...
# 16950         Games  Games, Strategy, Entertainment, Puzzle
# 16956         Games  Games, Entertainment, Action, Strategy
# 16962         Games             Games, Simulation, Strategy
# 16967         Games             Games, Simulation, Strategy
# 16993         Games       Games, Strategy, Board, Utilities
#
#       Original Release Date Current Version Release Date
# 0                11/07/2008                   30/05/2017
# 1                11/07/2008                   17/05/2018
# 2                11/07/2008                    5/09/2017
# 3                23/07/2008                   30/05/2017
# 4                18/07/2008                   22/07/2018
# ...                     ...                          ...
# 16950            31/07/2019                   31/07/2019
# 16956            23/07/2019                   23/07/2019
# 16962            31/07/2019                   31/07/2019
# 16967            28/07/2019                   28/07/2019
# 16993            30/07/2019                   30/07/2019
#
# [7561 rows x 18 columns]

# %%
data.dropna(subset = ["price"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-e1efc57735f8> in <module>
# ----> 1 data.dropna(subset = ["price"])
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4746             check = indices == -1
#    4747             if check.any():
# -> 4748                 raise KeyError(list(np.compress(check, subset)))
#    4749             agg_obj = self.take(indices, axis=agg_axis)
#    4750
#
# KeyError: ['price']

# %%
data.dropna(subset = ["Price"])
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595   284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...   285755462
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# ...                                                  ...         ...
# 17002  https://apps.apple.com/us/app/stack-puzzle-ris...  1474626442
# 17003  https://apps.apple.com/us/app/eachother/id1474...  1474919257
# 17004  https://apps.apple.com/us/app/rabbit-vs-tortoi...  1474962324
# 17005  https://apps.apple.com/us/app/fatall/id1474963671  1474963671
# 17006  https://apps.apple.com/us/app/the-three-kingdo...  1475076711
#
#                             Name                        Subtitle  \
# 0                         Sudoku                             NaN
# 1                        Reversi                             NaN
# 2                        Morocco                             NaN
# 3                  Sudoku (Free)                             NaN
# 4                   Senet Deluxe                             NaN
# ...                          ...                             ...
# 17002  Stack Puzzle : Rise Tower  Blast the cubes, solve puzzle!
# 17003                  EachOther                             NaN
# 17004         Rabbit Vs Tortoise                             NaN
# 17005                     FaTaLL                Most fun game!!!
# 17006   The Three Kingdoms :Bomb                             NaN
#
#                                                 Icon URL  Average User Rating  \
# 0      https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 1      https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 2      https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 3      https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 4      https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# ...                                                  ...                  ...
# 17002  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 17003  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 17004  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 17005  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
# 17006  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  NaN
#
#        User Rating Count  Price   In-app Purchases  \
# 0                 3553.0   2.99                NaN
# 1                  284.0   1.99                NaN
# 2                 8376.0   0.00                NaN
# 3               190394.0   0.00                NaN
# 4                   28.0   2.99                NaN
# ...                  ...    ...                ...
# 17002                NaN   0.00                NaN
# 17003                NaN   0.00                NaN
# 17004                NaN   0.00                NaN
# 17005                NaN   0.00  9.99, 49.99, 3.99
# 17006                NaN   0.00                NaN
#
#                                              Description  \
# 0      Join over 21,000,000 of our fans and download ...
# 1      The classic game of Reversi, also known as Oth...
# 2      Play the classic strategy game Othello (also k...
# 3      Top 100 free app for over a year.\nRated "Best...
# 4      "Senet Deluxe - The Ancient Game of Life and A...
# ...                                                  ...
# 17002  The goal is very simple, move the square horiz...
# 17003  Collect a score while you play!!\n\nBy linking...
# 17004  "Rabbit Vs Tortoise is chess type cool simple ...
# 17005  Upgrade your character and use your skills to ...
# 17006  The protagonist uses the method of placing a b...
#
#                       Developer Age Rating  \
# 0      Mighty Mighty Good Games         4+
# 1              Kiss The Machine         4+
# 2                   Bayou Games         4+
# 3      Mighty Mighty Good Games         4+
# 4               RoGame Software         4+
# ...                         ...        ...
# 17002               Zhigang Pei         4+
# 17003             Sultan Shindi         4+
# 17004             Vishal Baldha         4+
# 17005              Tayrem Games         4+
# 17006              ming bo tang         4+
#
#                                                Languages         Size  \
# 0      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   15853568.0
# 1                                                     EN   12328960.0
# 2                                                     EN     674816.0
# 3      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   21552128.0
# 4      DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...   34689024.0
# ...                                                  ...          ...
# 17002                                                 EN   64795648.0
# 17003                                                 EN  110341120.0
# 17004                                                 EN   23207936.0
# 17005                                                 EN  196750336.0
# 17006                                             EN, ZH   22952960.0
#
#       Primary Genre                                  Genres  \
# 0             Games                 Games, Strategy, Puzzle
# 1             Games                  Games, Strategy, Board
# 2             Games                  Games, Board, Strategy
# 3             Games                 Games, Strategy, Puzzle
# 4             Games       Games, Strategy, Board, Education
# ...             ...                                     ...
# 17002         Games  Games, Entertainment, Casual, Strategy
# 17003         Games                 Games, Family, Strategy
# 17004         Games                         Games, Strategy
# 17005         Games                 Games, Strategy, Action
# 17006         Games                 Games, Strategy, Puzzle
#
#       Original Release Date Current Version Release Date
# 0                11/07/2008                   30/05/2017
# 1                11/07/2008                   17/05/2018
# 2                11/07/2008                    5/09/2017
# 3                23/07/2008                   30/05/2017
# 4                18/07/2008                   22/07/2018
# ...                     ...                          ...
# 17002            30/07/2019                   30/07/2019
# 17003             1/08/2019                    1/08/2019
# 17004             3/08/2019                    3/08/2019
# 17005             1/08/2019                    1/08/2019
# 17006             2/08/2019                    2/08/2019
#
# [16983 rows x 18 columns]

# %%
data.dropna(subset = ["User Rating Count"], inplace = True)

# %%
data.dropna(subset = ["Price"], inplace = True)

# %%
data
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595   284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...   285755462
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# ...                                                  ...         ...
# 16950  https://apps.apple.com/us/app/die-last/id14730...  1473084135
# 16956  https://apps.apple.com/us/app/basic-slosh/id14...  1473181500
# 16962  https://apps.apple.com/us/app/idle-racing-tyco...  1473559573
# 16967  https://apps.apple.com/us/app/glow-hockey-stri...  1473680543
# 16993  https://apps.apple.com/us/app/agadmator-chess-...  1474461379
#
#                         Name                       Subtitle  \
# 0                     Sudoku                            NaN
# 1                    Reversi                            NaN
# 2                    Morocco                            NaN
# 3              Sudoku (Free)                            NaN
# 4               Senet Deluxe                            NaN
# ...                      ...                            ...
# 16950               Die Last                Who can survive
# 16956            Basic Slosh                            NaN
# 16962     Idle Racing Tycoon    Develop Your Car Racing Inc
# 16967     Glow Hockey Strike  Best 2 player air hockey game
# 16993  Agadmator Chess Clock   Simple & elegant chess clock
#
#                                                 Icon URL  Average User Rating  \
# 0      https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 1      https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 2      https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 3      https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 4      https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# ...                                                  ...                  ...
# 16950  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 16956  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16962  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16967  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16993  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
#
#        User Rating Count  Price In-app Purchases  \
# 0                 3553.0   2.99              NaN
# 1                  284.0   1.99              NaN
# 2                 8376.0   0.00              NaN
# 3               190394.0   0.00              NaN
# 4                   28.0   2.99              NaN
# ...                  ...    ...              ...
# 16950                6.0   0.00              NaN
# 16956               30.0   0.00              NaN
# 16962               51.0   0.00              NaN
# 16967                5.0   0.00              NaN
# 16993               33.0   0.00              NaN
#
#                                              Description  \
# 0      Join over 21,000,000 of our fans and download ...
# 1      The classic game of Reversi, also known as Oth...
# 2      Play the classic strategy game Othello (also k...
# 3      Top 100 free app for over a year.\nRated "Best...
# 4      "Senet Deluxe - The Ancient Game of Life and A...
# ...                                                  ...
# 16950  "Welcome to this mysterious room full of gears...
# 16956  "Take the ball to safety and reach the next le...
# 16962  Build your racing circuit.\n\nRecruit visitors...
# 16967  Glow Hockey Strike is a cool colorful air hock...
# 16993  Agadmator Chess Clock is a beautiful, lightwei...
#
#                       Developer Age Rating  \
# 0      Mighty Mighty Good Games         4+
# 1              Kiss The Machine         4+
# 2                   Bayou Games         4+
# 3      Mighty Mighty Good Games         4+
# 4               RoGame Software         4+
# ...                         ...        ...
# 16950                  Jie Yang        12+
# 16956          Ashnell Marchand         4+
# 16962              Carson Brody         9+
# 16967              Samir Jabeur         4+
# 16993              Ivan Amidzic         4+
#
#                                                Languages         Size  \
# 0      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   15853568.0
# 1                                                     EN   12328960.0
# 2                                                     EN     674816.0
# 3      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   21552128.0
# 4      DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...   34689024.0
# ...                                                  ...          ...
# 16950                                             EN, ZH  151308288.0
# 16956                                                 EN   79646720.0
# 16962                                                 EN  125348864.0
# 16967                                                 EN  128687104.0
# 16993                                                 EN    8845312.0
#
#       Primary Genre                                  Genres  \
# 0             Games                 Games, Strategy, Puzzle
# 1             Games                  Games, Strategy, Board
# 2             Games                  Games, Board, Strategy
# 3             Games                 Games, Strategy, Puzzle
# 4             Games       Games, Strategy, Board, Education
# ...             ...                                     ...
# 16950         Games  Games, Strategy, Entertainment, Puzzle
# 16956         Games  Games, Entertainment, Action, Strategy
# 16962         Games             Games, Simulation, Strategy
# 16967         Games             Games, Simulation, Strategy
# 16993         Games       Games, Strategy, Board, Utilities
#
#       Original Release Date Current Version Release Date
# 0                11/07/2008                   30/05/2017
# 1                11/07/2008                   17/05/2018
# 2                11/07/2008                    5/09/2017
# 3                23/07/2008                   30/05/2017
# 4                18/07/2008                   22/07/2018
# ...                     ...                          ...
# 16950            31/07/2019                   31/07/2019
# 16956            23/07/2019                   23/07/2019
# 16962            31/07/2019                   31/07/2019
# 16967            28/07/2019                   28/07/2019
# 16993            30/07/2019                   30/07/2019
#
# [7561 rows x 18 columns]

# %%
data.isnull().sum()
# Out:
# URL                                0
# ID                                 0
# Name                               0
# Subtitle                        4837
# Icon URL                           0
# Average User Rating                0
# User Rating Count                  0
# Price                              0
# In-app Purchases                2927
# Description                        0
# Developer                          0
# Age Rating                         0
# Languages                         24
# Size                               0
# Primary Genre                      0
# Genres                             0
# Original Release Date              0
# Current Version Release Date       0
# dtype: int64

# %%
pd.DataFrame(data["In-app Purchases"].unique())
# Out:
#                                                       0
# 0                                                   NaN
# 1                                                  1.99
# 2                                                  0.99
# 3              1.99, 0.99, 1.99, 0.99, 4.99, 1.99, 1.99
# 4                                      0.99, 0.99, 0.99
# ...                                                 ...
# 2961                            4.99, 0.99, 11.99, 1.99
# 2962                       0.99, 1.99, 2.99, 3.99, 0.99
# 2963  7.99, 13.99, 2.99, 3.99, 7.99, 1.99, 1.99, 16....
# 2964     4.99, 1.99, 9.99, 4.99, 4.99, 4.99, 4.99, 4.99
# 2965  1.99, 1.99, 1.99, 2.99, 5.99, 3.99, 5.99, 2.99...
#
# [2966 rows x 1 columns]

# %%
data["In-app Purchases"].head(60)
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                  1.99
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                 0.99
# 16                                                 0.99
# 17                                                  NaN
# 18             1.99, 0.99, 1.99, 0.99, 4.99, 1.99, 1.99
# 19                                     0.99, 0.99, 0.99
# 20                                                  NaN
# 21                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                               0.99, 0.99, 0.99, 0.99
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# 30                                                  NaN
# 31                                           1.99, 0.99
# 32                                                  NaN
# 33                                                  NaN
# 34                                                  NaN
# 35                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38                                     0.99, 2.99, 1.99
# 39                                                  NaN
# 40                                                  NaN
# 41                                                  NaN
# 42                                                  NaN
# 43                                                  NaN
# 44                                                  NaN
# 45                                                  NaN
# 46                                                  NaN
# 47                                                  NaN
# 48                                                  NaN
# 49                                                  NaN
# 50                                                  NaN
# 51                                                  NaN
# 52                                                  NaN
# 53                                                  NaN
# 54                                                 1.99
# 55                                                  NaN
# 58                                                  NaN
# 59    0.0, 0.99, 5.99, 0.99, 0.99, 0.99, 0.99, 0.99,...
# 60                                                  NaN
# 61                                                  NaN
# 62                                                  NaN
# 63                                                  NaN
# 64                                                  NaN
# Name: In-app Purchases, dtype: object

# %%
data["Price"].unique()
# Out:
# array([  2.99,   1.99,   0.  ,   0.99,   5.99,   7.99,   4.99,   3.99,
#          9.99,  19.99,   6.99,  11.99,   8.99, 139.99,  12.99,  14.99,
#         16.99,  36.99,  59.99])

# %%
data["Price"].h
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 2      https://apps.apple.com/us/app/morocco/id284946595   284946595
# 3      https://apps.apple.com/us/app/sudoku-free/id28...   285755462
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# ...                                                  ...         ...
# 16950  https://apps.apple.com/us/app/die-last/id14730...  1473084135
# 16956  https://apps.apple.com/us/app/basic-slosh/id14...  1473181500
# 16962  https://apps.apple.com/us/app/idle-racing-tyco...  1473559573
# 16967  https://apps.apple.com/us/app/glow-hockey-stri...  1473680543
# 16993  https://apps.apple.com/us/app/agadmator-chess-...  1474461379
#
#                         Name                       Subtitle  \
# 0                     Sudoku                            NaN
# 1                    Reversi                            NaN
# 2                    Morocco                            NaN
# 3              Sudoku (Free)                            NaN
# 4               Senet Deluxe                            NaN
# ...                      ...                            ...
# 16950               Die Last                Who can survive
# 16956            Basic Slosh                            NaN
# 16962     Idle Racing Tycoon    Develop Your Car Racing Inc
# 16967     Glow Hockey Strike  Best 2 player air hockey game
# 16993  Agadmator Chess Clock   Simple & elegant chess clock
#
#                                                 Icon URL  Average User Rating  \
# 0      https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 1      https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 2      https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 3      https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 4      https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# ...                                                  ...                  ...
# 16950  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 16956  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16962  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16967  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16993  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
#
#        User Rating Count  Price In-app Purchases  \
# 0                 3553.0   2.99              NaN
# 1                  284.0   1.99              NaN
# 2                 8376.0   0.00              NaN
# 3               190394.0   0.00              NaN
# 4                   28.0   2.99              NaN
# ...                  ...    ...              ...
# 16950                6.0   0.00              NaN
# 16956               30.0   0.00              NaN
# 16962               51.0   0.00              NaN
# 16967                5.0   0.00              NaN
# 16993               33.0   0.00              NaN
#
#                                              Description  \
# 0      Join over 21,000,000 of our fans and download ...
# 1      The classic game of Reversi, also known as Oth...
# 2      Play the classic strategy game Othello (also k...
# 3      Top 100 free app for over a year.\nRated "Best...
# 4      "Senet Deluxe - The Ancient Game of Life and A...
# ...                                                  ...
# 16950  "Welcome to this mysterious room full of gears...
# 16956  "Take the ball to safety and reach the next le...
# 16962  Build your racing circuit.\n\nRecruit visitors...
# 16967  Glow Hockey Strike is a cool colorful air hock...
# 16993  Agadmator Chess Clock is a beautiful, lightwei...
#
#                       Developer Age Rating  \
# 0      Mighty Mighty Good Games         4+
# 1              Kiss The Machine         4+
# 2                   Bayou Games         4+
# 3      Mighty Mighty Good Games         4+
# 4               RoGame Software         4+
# ...                         ...        ...
# 16950                  Jie Yang        12+
# 16956          Ashnell Marchand         4+
# 16962              Carson Brody         9+
# 16967              Samir Jabeur         4+
# 16993              Ivan Amidzic         4+
#
#                                                Languages         Size  \
# 0      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   15853568.0
# 1                                                     EN   12328960.0
# 2                                                     EN     674816.0
# 3      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   21552128.0
# 4      DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...   34689024.0
# ...                                                  ...          ...
# 16950                                             EN, ZH  151308288.0
# 16956                                                 EN   79646720.0
# 16962                                                 EN  125348864.0
# 16967                                                 EN  128687104.0
# 16993                                                 EN    8845312.0
#
#       Primary Genre                                  Genres  \
# 0             Games                 Games, Strategy, Puzzle
# 1             Games                  Games, Strategy, Board
# 2             Games                  Games, Board, Strategy
# 3             Games                 Games, Strategy, Puzzle
# 4             Games       Games, Strategy, Board, Education
# ...             ...                                     ...
# 16950         Games  Games, Strategy, Entertainment, Puzzle
# 16956         Games  Games, Entertainment, Action, Strategy
# 16962         Games             Games, Simulation, Strategy
# 16967         Games             Games, Simulation, Strategy
# 16993         Games       Games, Strategy, Board, Utilities
#
#       Original Release Date Current Version Release Date
# 0                11/07/2008                   30/05/2017
# 1                11/07/2008                   17/05/2018
# 2                11/07/2008                    5/09/2017
# 3                23/07/2008                   30/05/2017
# 4                18/07/2008                   22/07/2018
# ...                     ...                          ...
# 16950            31/07/2019                   31/07/2019
# 16956            23/07/2019                   23/07/2019
# 16962            31/07/2019                   31/07/2019
# 16967            28/07/2019                   28/07/2019
# 16993            30/07/2019                   30/07/2019
#
# [7561 rows x 18 columns]

# %%
import matplotlib.pyplot as plt

# %%
x = data["Price"].unique()

# %%
x
# Out:
# array([  2.99,   1.99,   0.  ,   0.99,   5.99,   7.99,   4.99,   3.99,
#          9.99,  19.99,   6.99,  11.99,   8.99, 139.99,  12.99,  14.99,
#         16.99,  36.99,  59.99])

# %%
import collections

# %%
freq = collections.Counter(data["Price"])
freq
# Out:
# Counter({2.99: 252,
#          1.99: 201,
#          0.0: 6325,
#          0.99: 352,
#          5.99: 28,
#          7.99: 10,
#          4.99: 185,
#          3.99: 105,
#          9.99: 48,
#          19.99: 5,
#          6.99: 26,
#          11.99: 3,
#          8.99: 12,
#          139.99: 1,
#          12.99: 3,
#          14.99: 2,
#          16.99: 1,
#          36.99: 1,
#          59.99: 1})

# %%
x = freq.keys()
x
# Out:
# dict_keys([2.99, 1.99, 0.0, 0.99, 5.99, 7.99, 4.99, 3.99, 9.99, 19.99, 6.99, 11.99, 8.99, 139.99, 12.99, 14.99, 16.99, 36.99, 59.99])

# %%
y = freq.values()
y
# Out:
# dict_values([252, 201, 6325, 352, 28, 10, 185, 105, 48, 5, 26, 3, 12, 1, 3, 2, 1, 1, 1])

# %%
plt.plot(list(x), list(y))

# %%
data[data["Price"] != 0.0]
# Out:
#                                                      URL          ID  \
# 0       https://apps.apple.com/us/app/sudoku/id284921427   284921427
# 1      https://apps.apple.com/us/app/reversi/id284926400   284926400
# 4      https://apps.apple.com/us/app/senet-deluxe/id2...   285831220
# 7       https://apps.apple.com/us/app/colony/id286363959   286363959
# 13      https://apps.apple.com/us/app/marple/id288689440   288689440
# ...                                                  ...         ...
# 16447  https://apps.apple.com/us/app/spellsword-cards...  1459350707
# 16463  https://apps.apple.com/us/app/theotown/id14596...  1459639864
# 16548  https://apps.apple.com/us/app/papas-donuteria-...  1462324486
# 16569  https://apps.apple.com/us/app/great-conqueror-...  1462722690
# 16850  https://apps.apple.com/us/app/p1-select/id1470...  1470639614
#
#                             Name                      Subtitle  \
# 0                         Sudoku                           NaN
# 1                        Reversi                           NaN
# 4                   Senet Deluxe                           NaN
# 7                         Colony                           NaN
# 13                        Marple                           NaN
# ...                          ...                           ...
# 16447  Spellsword Cards: Origins     Roguelike Deckbuilder RPG
# 16463                   TheoTown  A classic city builder game.
# 16548  "Papa's Donuteria To Go!"       Serve delicious donuts!
# 16569      Great Conqueror: Rome  Turn-based War Strategy Game
# 16850                  P1 Select                           NaN
#
#                                                 Icon URL  Average User Rating  \
# 0      https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 1      https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 4      https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 7      https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  2.5
# 13     https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# ...                                                  ...                  ...
# 16447  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 16463  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16548  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16569  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 16850  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
#
#        User Rating Count  Price  \
# 0                 3553.0   2.99
# 1                  284.0   1.99
# 4                   28.0   2.99
# 7                  125.0   0.99
# 13                 989.0   0.99
# ...                  ...    ...
# 16447               73.0   2.99
# 16463               50.0   3.99
# 16548               80.0   1.99
# 16569              105.0   0.99
# 16850               22.0   2.99
#
#                                         In-app Purchases  \
# 0                                                    NaN
# 1                                                    NaN
# 4                                                    NaN
# 7                                                    NaN
# 13                                                   NaN
# ...                                                  ...
# 16447                                                NaN
# 16463                                                NaN
# 16548                 4.99, 1.99, 0.99, 4.99, 1.99, 0.99
# 16569  10.99, 1.99, 1.99, 1.99, 8.99, 19.99, 9.99, 7....
# 16850                                                NaN
#
#                                              Description  \
# 0      Join over 21,000,000 of our fans and download ...
# 1      The classic game of Reversi, also known as Oth...
# 4      "Senet Deluxe - The Ancient Game of Life and A...
# 7      "50 levels of addictive puzzling strategy fun!...
# 13     AWARDED "BEST PUZZLER" IN MACWORLD\'S "THE BES...
# ...                                                  ...
# 16447  Featuring 500+ cards and counting, 10 classes,...
# 16463  TheoTown is a city building game in which you ...
# 16548  Fry and serve delicious donuts in Papa\'s Donu...
# 16569  "Commander!\xa0The\xa0Roman\xa0Republic\xa0is\...
# 16850  New mini roguelike "broughlike" game.  Explore...
#
#                                    Developer Age Rating  \
# 0                   Mighty Mighty Good Games         4+
# 1                           Kiss The Machine         4+
# 4                            RoGame Software         4+
# 7                               Chris Haynes         4+
# 13                           Mikko Kankainen         4+
# ...                                      ...        ...
# 16447                            One Up Plus         9+
# 16463  blueflower UG (haftungsbeschr\xe4nkt)         9+
# 16548                       Flipline Studios         4+
# 16569                              EASY Inc.         9+
# 16850                         Michael Brough         9+
#
#                                                Languages         Size  \
# 0      DA, NL, EN, FI, FR, DE, IT, JA, KO, NB, PL, PT...   15853568.0
# 1                                                     EN   12328960.0
# 4      DA, NL, EN, FR, DE, EL, IT, JA, KO, NO, PT, RU...   34689024.0
# 7                                                     EN   64333824.0
# 13                                                    EN    3643392.0
# ...                                                  ...          ...
# 16447                                         ZH, EN, ZH  188120064.0
# 16463                                                NaN  116820992.0
# 16548                                                 EN   90510336.0
# 16569                                 EN, JA, KO, ZH, ZH  219094016.0
# 16850                                                 EN    4917248.0
#
#       Primary Genre                                      Genres  \
# 0             Games                     Games, Strategy, Puzzle
# 1             Games                      Games, Strategy, Board
# 4             Games           Games, Strategy, Board, Education
# 7             Games                      Games, Strategy, Board
# 13            Games                     Games, Puzzle, Strategy
# ...             ...                                         ...
# 16447         Games        Games, Card, Strategy, Entertainment
# 16463         Games  Games, Simulation, Entertainment, Strategy
# 16548         Games                 Games, Strategy, Simulation
# 16569         Games                 Games, Strategy, Simulation
# 16850         Games                     Games, Strategy, Puzzle
#
#       Original Release Date Current Version Release Date
# 0                11/07/2008                   30/05/2017
# 1                11/07/2008                   17/05/2018
# 4                18/07/2008                   22/07/2018
# 7                 3/08/2008                    3/10/2018
# 13               28/08/2008                    5/05/2019
# ...                     ...                          ...
# 16447             2/05/2019                   29/07/2019
# 16463            20/05/2019                   28/06/2019
# 16548             7/06/2019                   16/07/2019
# 16569            27/06/2019                   27/07/2019
# 16850            21/07/2019                   21/07/2019
#
# [1236 rows x 18 columns]

# %%
data = data[data["Price"] != 0.0]

# %%
data.isnull().sum()
# Out:
# URL                               0
# ID                                0
# Name                              0
# Subtitle                        865
# Icon URL                          0
# Average User Rating               0
# User Rating Count                 0
# Price                             0
# In-app Purchases                853
# Description                       0
# Developer                         0
# Age Rating                        0
# Languages                         2
# Size                              0
# Primary Genre                     0
# Genres                            0
# Original Release Date             0
# Current Version Release Date      0
# dtype: int64

# %%
data = data.dropna(subset=["In-app Purchases"])
data
# Out:
#                                                      URL          ID  \
# 26     https://apps.apple.com/us/app/fieldrunners/id2...   292421271
# 59     https://apps.apple.com/us/app/wedding-dash-del...   303337299
# 70        https://apps.apple.com/us/app/slay/id305324342   305324342
# 91     https://apps.apple.com/us/app/pocket-tanks-del...   311466554
# 102    https://apps.apple.com/us/app/boxed-in/id31446...   314464100
# ...                                                  ...         ...
# 15574  https://apps.apple.com/us/app/pirates-outlaws/...  1442776789
# 16079  https://apps.apple.com/us/app/papas-wingeria-t...  1451873044
# 16305  https://apps.apple.com/us/app/santorini-board-...  1456647343
# 16548  https://apps.apple.com/us/app/papas-donuteria-...  1462324486
# 16569  https://apps.apple.com/us/app/great-conqueror-...  1462722690
#
#                             Name                        Subtitle  \
# 26                  Fieldrunners                             NaN
# 59           Wedding Dash Deluxe                             NaN
# 70                          Slay                             NaN
# 91           Pocket Tanks Deluxe                             NaN
# 102                     Boxed In                             NaN
# ...                          ...                             ...
# 15574            Pirates Outlaws       Indie roguelike card game
# 16079   "Papa's Wingeria To Go!"         Saucy wings and things!
# 16305       Santorini Board Game  Learn in 30 sec, play for life
# 16548  "Papa's Donuteria To Go!"         Serve delicious donuts!
# 16569      Great Conqueror: Rome    Turn-based War Strategy Game
#
#                                                 Icon URL  Average User Rating  \
# 26     https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 59     https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 70     https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 91     https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 102    https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# ...                                                  ...                  ...
# 15574  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 16079  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16305  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 16548  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16569  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
#
#        User Rating Count  Price  \
# 26               41869.0   2.99
# 59               17056.0   0.99
# 70                4885.0   3.99
# 91                5543.0   4.99
# 102              93235.0   0.99
# ...                  ...    ...
# 15574              705.0   0.99
# 16079               51.0   1.99
# 16305               20.0   4.99
# 16548               80.0   1.99
# 16569              105.0   0.99
#
#                                         In-app Purchases  \
# 26                                0.99, 0.99, 0.99, 0.99
# 59     0.0, 0.99, 5.99, 0.99, 0.99, 0.99, 0.99, 0.99,...
# 70     9.99, 9.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99...
# 91     0.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99...
# 102    0.99, 0.99, 0.99, 1.99, 0.99, 2.99, 4.99, 0.99...
# ...                                                  ...
# 15574                 2.99, 4.99, 4.99, 1.99, 0.99, 8.99
# 16079                 4.99, 0.99, 1.99, 0.99, 4.99, 1.99
# 16305     7.99, 0.99, 1.99, 0.99, 1.99, 1.99, 3.99, 5.99
# 16548                 4.99, 1.99, 0.99, 4.99, 1.99, 0.99
# 16569  10.99, 1.99, 1.99, 1.99, 8.99, 19.99, 9.99, 7....
#
#                                              Description  \
# 26     OVERVIEW\n\nThe invasion begins!  Pint sized s...
# 59     * Play the most romantic Dash game! With over ...
# 70     Slay is a simple to learn game of strategy and...
# 91     "The Ultimate One-on-One Artillery Game" \u201...
# 102    Ready to try one of the best puzzle games in t...
# ...                                                  ...
# 15574  "Play cards, build your deck to get the best c...
# 16079  Fry and toss tons of saucy wings and things in...
# 16305  Santorini is a highly accessible pure strategy...
# 16548  Fry and serve delicious donuts in Papa\'s Donu...
# 16569  "Commander!\xa0The\xa0Roman\xa0Republic\xa0is\...
#
#                        Developer Age Rating           Languages         Size  \
# 26        Subatomic Studios, LLC         9+                  EN   75041792.0
# 59                 Glu Games Inc         4+                  EN   55803904.0
# 70               "Sean O'Connor"         9+                  EN   59016192.0
# 91     Blitwise Productions, LLC         9+                  EN   39997440.0
# 102               Dennis Mengelt         4+                  EN  259371008.0
# ...                          ...        ...                 ...          ...
# 15574        Fabled Game Limited         9+              EN, ZH  150626304.0
# 16079           Flipline Studios         4+                  EN   73931776.0
# 16305                     Roxley         4+                  EN  467159040.0
# 16548           Flipline Studios         4+                  EN   90510336.0
# 16569                  EASY Inc.         9+  EN, JA, KO, ZH, ZH  219094016.0
#
#       Primary Genre                                  Genres  \
# 26            Games  Games, Entertainment, Action, Strategy
# 59            Games  Games, Strategy, Action, Entertainment
# 70            Games                  Games, Board, Strategy
# 91            Games  Games, Family, Strategy, Entertainment
# 102           Games  Games, Strategy, Entertainment, Puzzle
# ...             ...                                     ...
# 15574         Games    Games, Card, Strategy, Entertainment
# 16079         Games             Games, Simulation, Strategy
# 16305         Games   Games, Entertainment, Strategy, Board
# 16548         Games             Games, Strategy, Simulation
# 16569         Games             Games, Strategy, Simulation
#
#       Original Release Date Current Version Release Date
# 26                5/10/2008                   11/04/2018
# 59               28/01/2009                    2/07/2014
# 70               27/02/2009                   30/05/2019
# 91               15/04/2009                   31/08/2016
# 102               6/05/2009                    4/12/2017
# ...                     ...                          ...
# 15574             6/03/2019                    3/08/2019
# 16079            23/02/2019                    8/03/2019
# 16305            13/07/2019                   18/07/2019
# 16548             7/06/2019                   16/07/2019
# 16569            27/06/2019                   27/07/2019
#
# [383 rows x 18 columns]

# %%
data.groupby("Genres")

# %%
data
# Out:
#                                                      URL          ID  \
# 26     https://apps.apple.com/us/app/fieldrunners/id2...   292421271
# 59     https://apps.apple.com/us/app/wedding-dash-del...   303337299
# 70        https://apps.apple.com/us/app/slay/id305324342   305324342
# 91     https://apps.apple.com/us/app/pocket-tanks-del...   311466554
# 102    https://apps.apple.com/us/app/boxed-in/id31446...   314464100
# ...                                                  ...         ...
# 15574  https://apps.apple.com/us/app/pirates-outlaws/...  1442776789
# 16079  https://apps.apple.com/us/app/papas-wingeria-t...  1451873044
# 16305  https://apps.apple.com/us/app/santorini-board-...  1456647343
# 16548  https://apps.apple.com/us/app/papas-donuteria-...  1462324486
# 16569  https://apps.apple.com/us/app/great-conqueror-...  1462722690
#
#                             Name                        Subtitle  \
# 26                  Fieldrunners                             NaN
# 59           Wedding Dash Deluxe                             NaN
# 70                          Slay                             NaN
# 91           Pocket Tanks Deluxe                             NaN
# 102                     Boxed In                             NaN
# ...                          ...                             ...
# 15574            Pirates Outlaws       Indie roguelike card game
# 16079   "Papa's Wingeria To Go!"         Saucy wings and things!
# 16305       Santorini Board Game  Learn in 30 sec, play for life
# 16548  "Papa's Donuteria To Go!"         Serve delicious donuts!
# 16569      Great Conqueror: Rome    Turn-based War Strategy Game
#
#                                                 Icon URL  Average User Rating  \
# 26     https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 59     https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 70     https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 91     https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 102    https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# ...                                                  ...                  ...
# 15574  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 16079  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16305  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 16548  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 16569  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
#
#        User Rating Count  Price  \
# 26               41869.0   2.99
# 59               17056.0   0.99
# 70                4885.0   3.99
# 91                5543.0   4.99
# 102              93235.0   0.99
# ...                  ...    ...
# 15574              705.0   0.99
# 16079               51.0   1.99
# 16305               20.0   4.99
# 16548               80.0   1.99
# 16569              105.0   0.99
#
#                                         In-app Purchases  \
# 26                                0.99, 0.99, 0.99, 0.99
# 59     0.0, 0.99, 5.99, 0.99, 0.99, 0.99, 0.99, 0.99,...
# 70     9.99, 9.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99...
# 91     0.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99...
# 102    0.99, 0.99, 0.99, 1.99, 0.99, 2.99, 4.99, 0.99...
# ...                                                  ...
# 15574                 2.99, 4.99, 4.99, 1.99, 0.99, 8.99
# 16079                 4.99, 0.99, 1.99, 0.99, 4.99, 1.99
# 16305     7.99, 0.99, 1.99, 0.99, 1.99, 1.99, 3.99, 5.99
# 16548                 4.99, 1.99, 0.99, 4.99, 1.99, 0.99
# 16569  10.99, 1.99, 1.99, 1.99, 8.99, 19.99, 9.99, 7....
#
#                                              Description  \
# 26     OVERVIEW\n\nThe invasion begins!  Pint sized s...
# 59     * Play the most romantic Dash game! With over ...
# 70     Slay is a simple to learn game of strategy and...
# 91     "The Ultimate One-on-One Artillery Game" \u201...
# 102    Ready to try one of the best puzzle games in t...
# ...                                                  ...
# 15574  "Play cards, build your deck to get the best c...
# 16079  Fry and toss tons of saucy wings and things in...
# 16305  Santorini is a highly accessible pure strategy...
# 16548  Fry and serve delicious donuts in Papa\'s Donu...
# 16569  "Commander!\xa0The\xa0Roman\xa0Republic\xa0is\...
#
#                        Developer Age Rating           Languages         Size  \
# 26        Subatomic Studios, LLC         9+                  EN   75041792.0
# 59                 Glu Games Inc         4+                  EN   55803904.0
# 70               "Sean O'Connor"         9+                  EN   59016192.0
# 91     Blitwise Productions, LLC         9+                  EN   39997440.0
# 102               Dennis Mengelt         4+                  EN  259371008.0
# ...                          ...        ...                 ...          ...
# 15574        Fabled Game Limited         9+              EN, ZH  150626304.0
# 16079           Flipline Studios         4+                  EN   73931776.0
# 16305                     Roxley         4+                  EN  467159040.0
# 16548           Flipline Studios         4+                  EN   90510336.0
# 16569                  EASY Inc.         9+  EN, JA, KO, ZH, ZH  219094016.0
#
#       Primary Genre                                  Genres  \
# 26            Games  Games, Entertainment, Action, Strategy
# 59            Games  Games, Strategy, Action, Entertainment
# 70            Games                  Games, Board, Strategy
# 91            Games  Games, Family, Strategy, Entertainment
# 102           Games  Games, Strategy, Entertainment, Puzzle
# ...             ...                                     ...
# 15574         Games    Games, Card, Strategy, Entertainment
# 16079         Games             Games, Simulation, Strategy
# 16305         Games   Games, Entertainment, Strategy, Board
# 16548         Games             Games, Strategy, Simulation
# 16569         Games             Games, Strategy, Simulation
#
#       Original Release Date Current Version Release Date
# 26                5/10/2008                   11/04/2018
# 59               28/01/2009                    2/07/2014
# 70               27/02/2009                   30/05/2019
# 91               15/04/2009                   31/08/2016
# 102               6/05/2009                    4/12/2017
# ...                     ...                          ...
# 15574             6/03/2019                    3/08/2019
# 16079            23/02/2019                    8/03/2019
# 16305            13/07/2019                   18/07/2019
# 16548             7/06/2019                   16/07/2019
# 16569            27/06/2019                   27/07/2019
#
# [383 rows x 18 columns]

# %%
data.head(60)
# Out:
#                                                    URL         ID  \
# 26   https://apps.apple.com/us/app/fieldrunners/id2...  292421271
# 59   https://apps.apple.com/us/app/wedding-dash-del...  303337299
# 70      https://apps.apple.com/us/app/slay/id305324342  305324342
# 91   https://apps.apple.com/us/app/pocket-tanks-del...  311466554
# 102  https://apps.apple.com/us/app/boxed-in/id31446...  314464100
# 106  https://apps.apple.com/us/app/towermadness/id3...  316491616
# 126    https://apps.apple.com/us/app/worms/id321369231  321369231
# 128    https://apps.apple.com/us/app/pushy/id322110989  322110989
# 132  https://apps.apple.com/us/app/cartoon-wars/id3...  323242790
# 153  https://apps.apple.com/us/app/backgammon-nj/id...  328168559
# 167  https://apps.apple.com/us/app/millionaire-tyco...  332424440
# 180  https://apps.apple.com/us/app/catan-classic/id...  335029050
# 219  https://apps.apple.com/us/app/zen-wars/id34411...  344115274
# 247  https://apps.apple.com/us/app/worms-2-armagedd...  355524910
# 254  https://apps.apple.com/us/app/bubble-shooter-c...  357708798
# 257  https://apps.apple.com/us/app/shogi-lv-100-jap...  358617686
# 268  https://apps.apple.com/us/app/warlords-call-to...  363480718
# 269  https://apps.apple.com/us/app/worms-hd/id36350...  363503154
# 270  https://apps.apple.com/us/app/small-world-2/id...  364165557
# 300  https://apps.apple.com/us/app/erics-spider-sol...  367278729
# 303  https://apps.apple.com/us/app/shogi-lv-100-for...  367568101
# 309  https://apps.apple.com/us/app/towermadness-hd/...  368841090
# 318  https://apps.apple.com/us/app/backgammon-nj-hd...  371380665
# 323  https://apps.apple.com/us/app/blood-honor-no-a...  373002953
# 327  https://apps.apple.com/us/app/magic-alchemist/...  374143422
# 333  https://apps.apple.com/us/app/keno-pad/id37571...  375715528
# 343  https://apps.apple.com/us/app/aqueduct/id37754...  377544857
# 358  https://apps.apple.com/us/app/bubble-explode-p...  380862211
# 380  https://apps.apple.com/us/app/gunsnglory-premi...  385902072
# 401  https://apps.apple.com/us/app/catan-classic-hd...  390422167
# 408  https://apps.apple.com/us/app/neuroshima-hex/i...  391297152
# 421  https://apps.apple.com/us/app/airport-madness-...  393575110
# 431  https://apps.apple.com/us/app/sallys-spa-hd/id...  395232844
# 434  https://apps.apple.com/us/app/sentinel-3-homew...  396103539
# 438  https://apps.apple.com/us/app/cartoon-wars-2-h...  396837225
# 439  https://apps.apple.com/us/app/decked-builder/i...  397090691
# 441  https://apps.apple.com/us/app/hotel-dash-delux...  397836467
# 449  https://apps.apple.com/us/app/stratego-single-...  398975927
# 451  https://apps.apple.com/us/app/piperoll/id39922...  399226597
# 463  https://apps.apple.com/us/app/hotel-dash-suite...  401710533
# 475  https://apps.apple.com/us/app/bloons-td-4/id40...  404553553
# 482  https://apps.apple.com/us/app/robotngun/id4057...  405705981
# 495  https://apps.apple.com/us/app/euchre-hd/id4071...  407124620
# 500  https://apps.apple.com/us/app/hack-run/id40767...  407678003
# 545  https://apps.apple.com/us/app/dash-race/id4127...  412719734
# 564  https://apps.apple.com/us/app/anthill/id414658364  414658364
# 576  https://apps.apple.com/us/app/decked-builder-h...  416254013
# 589  https://apps.apple.com/us/app/gemcraft/id41851...  418510736
# 592  https://apps.apple.com/us/app/metawar/id418784843  418784843
# 636  https://apps.apple.com/us/app/great-little-war...  426392350
# 637  https://apps.apple.com/us/app/bloons-td-4-hd/i...  426415634
# 641  https://apps.apple.com/us/app/bobby-fischer-co...  426892039
# 644  https://apps.apple.com/us/app/forbidden-island...  427419772
# 645  https://apps.apple.com/us/app/garry-kasparovs-...  427480057
# 652  https://apps.apple.com/us/app/kasparovs-choice...  428875551
# 673  https://apps.apple.com/us/app/ticket-to-ride/i...  432504470
# 676  https://apps.apple.com/us/app/assault-commande...  432783861
# 688  https://apps.apple.com/us/app/400-arba3meyeh-m...  434815663
# 703  https://apps.apple.com/us/app/klaverjassen/id4...  436691368
# 738  https://apps.apple.com/us/app/defense-of-fortu...  442103631
#
#                                                  Name  \
# 26                                       Fieldrunners
# 59                                Wedding Dash Deluxe
# 70                                               Slay
# 91                                Pocket Tanks Deluxe
# 102                                          Boxed In
# 106                                      TowerMadness
# 126                                             WORMS
# 128                                             PUSHY
# 132                                      Cartoon Wars
# 153                                     Backgammon NJ
# 167                          MILLIONAIRE TYCOON\u2122
# 180                                     Catan Classic
# 219                                          Zen Wars
# 247                               Worms 2: Armageddon
# 254                            Bubble Shooter Classic
# 257                     Shogi Lv.100 (Japanese Chess)
# 268                            Warlords: Call To Arms
# 269                                          Worms HD
# 270                                     Small World 2
# 300                        "Eric's Spider Solitaire!"
# 303            Shogi Lv.100 for iPad (Japanese Chess)
# 309                                   TowerMadness HD
# 318                                  Backgammon NJ HD
# 323                              Blood & Honor No Ads
# 327                                   Magic Alchemist
# 333                                          Keno Pad
# 343                                          Aqueduct
# 358                                Bubble Explode Pro
# 380                            "Guns'n'Glory Premium"
# 401                                  Catan Classic HD
# 408                                    Neuroshima Hex
# 421                         Airport Madness Challenge
# 431                                  "Sally's Spa HD"
# 434                             Sentinel 3: Homeworld
# 438                            Cartoon Wars 2: Heroes
# 439                                    Decked Builder
# 441                                 Hotel Dash Deluxe
# 449                       Stratego \xae Single Player
# 451                                          PipeRoll
# 463                  Hotel Dash: Suite Success Deluxe
# 475                                       Bloons TD 4
# 482                                         RobotNGun
# 495                                         Euchre HD
# 500                                          Hack RUN
# 545                                         Dash Race
# 564                                           Anthill
# 576                                 Decked Builder HD
# 589                                          GemCraft
# 592                                           METAWAR
# 636                          Great Little War Game HD
# 637                                    Bloons TD 4 HD
# 641                 Bobby Fischer Complete Collection
# 644                                  Forbidden Island
# 645      "Garry Kasparov's Complete Chess Collection"
# 652  "Kasparov's Choice: 100 Influential Chess Games"
# 673                                    Ticket to Ride
# 676                        Assault Commander Ultimate
# 688                        400 Arba3meyeh Multiplayer
# 703                                      Klaverjassen
# 738                    Defense of Fortune: The Savior
#
#                            Subtitle  \
# 26                              NaN
# 59                              NaN
# 70                              NaN
# 91                              NaN
# 102                             NaN
# 106        Classic Defense Strategy
# 126                             NaN
# 128     A LOGIC GAME & A LOT OF FUN
# 132                             NaN
# 153                             NaN
# 167                             NaN
# 180            Trade, Build, Settle
# 219                             NaN
# 247                             NaN
# 254  Blow up bubbles and get points
# 257                             NaN
# 268                             NaN
# 269                             NaN
# 270                             NaN
# 300  Try all four challenging games
# 303                             NaN
# 309        Classic Defense Strategy
# 318                             NaN
# 323    Battle in online multiplayer
# 327                             NaN
# 333                             NaN
# 343          The Waterworks Puzzler
# 358           Pop And Shoot Bubbles
# 380      Wild west strategy defense
# 401            Trade, Build, Settle
# 408                             NaN
# 421                             NaN
# 431  Design Manage Build, have Fun!
# 434                             NaN
# 438                             NaN
# 439                             NaN
# 441                             NaN
# 449       Best strategy board game!
# 451                             NaN
# 463                             NaN
# 475                             NaN
# 482                             NaN
# 495                             NaN
# 500       Over 3 million downloads!
# 545                             NaN
# 564                             NaN
# 576                             NaN
# 589                             NaN
# 592                             NaN
# 636                             NaN
# 637                             NaN
# 641                             NaN
# 644       A co-operative adventure!
# 645                             NaN
# 652                             NaN
# 673             A railway adventure
# 676                             NaN
# 688                             NaN
# 703   "Be careful, it's addictive!"
# 738                             NaN
#
#                                               Icon URL  Average User Rating  \
# 26   https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 59   https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 70   https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.0
# 91   https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 102  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 106  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 126  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 128  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 132  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 153  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 167  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 180  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 219  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 247  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 254  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  2.5
# 257  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 268  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 269  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 270  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 300  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 303  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 309  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 318  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 323  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 327  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 333  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 343  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 358  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 380  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 401  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 408  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 421  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 431  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 434  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 438  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 439  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 441  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 449  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 451  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 463  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 475  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 482  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 495  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 500  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 545  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 564  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  5.0
# 576  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 589  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 592  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
# 636  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 637  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 641  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  2.0
# 644  https://is2-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 645  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  2.5
# 652  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  2.5
# 673  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 676  https://is3-ssl.mzstatic.com/image/thumb/Purpl...                  4.0
# 688  https://is4-ssl.mzstatic.com/image/thumb/Purpl...                  2.5
# 703  https://is5-ssl.mzstatic.com/image/thumb/Purpl...                  4.5
# 738  https://is1-ssl.mzstatic.com/image/thumb/Purpl...                  3.5
#
#      User Rating Count  Price  \
# 26             41869.0   2.99
# 59             17056.0   0.99
# 70              4885.0   3.99
# 91              5543.0   4.99
# 102            93235.0   0.99
# 106            42389.0   2.99
# 126             5778.0   1.99
# 128              163.0   1.99
# 132            35905.0   0.99
# 153             2567.0   4.99
# 167             4049.0   0.99
# 180            17440.0   4.99
# 219              184.0   0.99
# 247             9908.0   4.99
# 254              272.0   0.99
# 257               28.0   2.99
# 268             6230.0   1.99
# 269              579.0   1.99
# 270             1550.0   4.99
# 300             3344.0   0.99
# 303               15.0   3.99
# 309            18279.0   4.99
# 318             5326.0   7.99
# 323             3447.0   4.99
# 327               19.0   1.99
# 333               32.0   5.99
# 343             1312.0   2.99
# 358             1249.0   0.99
# 380             3298.0   2.99
# 401            11125.0   4.99
# 408             4516.0   4.99
# 421             1815.0   0.99
# 431             1920.0   4.99
# 434             2820.0   0.99
# 438            13147.0   0.99
# 439             1439.0   3.99
# 441            36217.0   0.99
# 449              832.0   2.99
# 451            18605.0   0.99
# 463             1006.0   2.99
# 475             8409.0   2.99
# 482             3330.0   0.99
# 495             1841.0   0.99
# 500             3455.0   0.99
# 545              167.0   0.99
# 564            12774.0   4.99
# 576              790.0   5.99
# 589             1174.0   2.99
# 592               16.0   0.99
# 636            19322.0   1.99
# 637             2582.0   2.99
# 641               16.0   1.99
# 644             1361.0   4.99
# 645                9.0   1.99
# 652                6.0   0.99
# 673             5755.0   6.99
# 676              199.0   1.99
# 688               22.0   0.99
# 703               28.0   2.99
# 738              337.0   0.99
#
#                                       In-app Purchases  \
# 26                              0.99, 0.99, 0.99, 0.99
# 59   0.0, 0.99, 5.99, 0.99, 0.99, 0.99, 0.99, 0.99,...
# 70   9.99, 9.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99...
# 91   0.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99...
# 102  0.99, 0.99, 0.99, 1.99, 0.99, 2.99, 4.99, 0.99...
# 106  1.99, 1.99, 1.99, 1.99, 1.99, 1.99, 1.99, 1.99...
# 126                                         0.99, 0.99
# 128                                               0.99
# 132                                   0.99, 5.99, 2.99
# 153                                   4.99, 2.99, 2.99
# 167                                         0.99, 0.99
# 180                       4.99, 9.99, 4.99, 1.99, 1.99
# 219                                         0.99, 0.99
# 247                                         0.99, 0.99
# 254                                               0.99
# 257                                        2.99, 11.99
# 268                                               0.99
# 269                                         0.99, 0.99
# 270                                   0.99, 0.99, 0.99
# 300                                               0.99
# 303                                               2.99
# 309  1.99, 1.99, 1.99, 1.99, 1.99, 1.99, 1.99, 1.99...
# 318                                   4.99, 2.99, 2.99
# 323  9.99, 4.99, 9.99, 0.99, 2.99, 0.99, 4.99, 0.99...
# 327                             0.99, 0.99, 1.99, 1.99
# 333                                   1.99, 4.99, 0.99
# 343                                   1.99, 1.99, 0.99
# 358                     1.99, 4.99, 9.99, 34.99, 39.99
# 380                                   0.99, 0.99, 7.99
# 401                       4.99, 4.99, 9.99, 1.99, 1.99
# 408  1.99, 1.99, 7.99, 1.99, 1.99, 1.99, 1.99, 1.99...
# 421  0.99, 2.99, 1.99, 3.99, 4.99, 1.99, 9.99, 9.99...
# 431                                               0.99
# 434                       1.99, 0.99, 0.99, 0.99, 0.99
# 438                 0.99, 2.99, 0.99, 9.99, 5.99, 5.99
# 439                                         2.99, 4.99
# 441             0.0, 0.0, 0.99, 2.99, 0.99, 0.99, 0.99
# 449                                               0.99
# 451                                         0.99, 0.99
# 463                                               0.99
# 475  6.99, 1.99, 2.99, 0.99, 0.99, 1.99, 1.99, 0.99...
# 482                             0.99, 0.99, 2.99, 1.99
# 495                                               2.99
# 500                                         0.99, 2.99
# 545                 2.99, 1.99, 0.99, 0.99, 0.99, 0.99
# 564                             0.99, 0.99, 0.99, 1.99
# 576                                         2.99, 4.99
# 589                     3.99, 9.99, 1.99, 27.99, 15.99
# 592                                               1.99
# 636                                         2.99, 2.99
# 637  6.99, 1.99, 2.99, 0.99, 0.99, 1.99, 1.99, 0.99...
# 641           3.99, 0.99, 0.99, 0.99, 0.99, 0.99, 0.99
# 644                                               0.99
# 645                       0.99, 0.99, 0.99, 0.99, 0.99
# 652                             0.99, 0.99, 0.99, 0.99
# 673  0.99, 2.99, 2.99, 2.99, 2.99, 2.99, 2.99, 2.99...
# 676                 0.99, 0.99, 0.99, 0.99, 0.99, 0.99
# 688                                         0.99, 0.99
# 703                                   0.99, 0.99, 0.99
# 738                     0.99, 4.99, 9.99, 99.99, 49.99
#
#                                            Description  \
# 26   OVERVIEW\n\nThe invasion begins!  Pint sized s...
# 59   * Play the most romantic Dash game! With over ...
# 70   Slay is a simple to learn game of strategy and...
# 91   "The Ultimate One-on-One Artillery Game" \u201...
# 102  Ready to try one of the best puzzle games in t...
# 106  Evil aliens are coming to turn your beloved sh...
# 126  "Run for cover as the original, award-winning ...
# 128  "BEST MOBILE APP FOR KIDS" Award\n(Children So...
# 132  "Cartoon Wars is an arcade war game which comb...
# 153  \u25cf GAME CENTER -- Play online, chat, invit...
# 167  "\u2022\u2022\u2022 #1 ITUNES BOARD GAME \u202...
# 180  "Catan", the legendary strategy game provides ...
# 219  Build your base, place your cannons and attack...
# 247  #1 Turn-Based Game in 135 countries - #1 Strat...
# 254  "Bubble Shooter is an extremely addictive matc...
# 257  Kanazawa Shogi Level 100 is the most popular S...
# 268  FREE for the next few days. Like the game? Gra...
# 269  "Run for cover as the original, award-winning ...
# 270  *** HAPPY SUMMER! Download Small World 2 at a ...
# 300  Play this 5-star, top-rated Spider solitaire o...
# 303  Shogi Lv.100 for iPad is the most popular Shog...
# 309  The most downloaded 3D tower defense strategy ...
# 318  \u25cf GAME CENTER -- Play online, chat, invit...
# 323  Classic board gameplay spiced up with card sup...
# 327  A magical game!\n\nOn your journey to become t...
# 333  "This retro style Keno game looks beautiful on...
# 343  Welcome to Aqueduct \u2013 a world of jumbled ...
# 358  You can try Bubble Explode for FREE: Search fo...
# 380  "Who needs heroes when you can play the bad gu...
# 401  "Catan", the legendary strategy game provides ...
# 408  AWARDS:\n"iOS Game of the Year"\nGame Shark\n\...
# 421  Earn experience and unlock new, awesome, FREE ...
# 431  \u25a0 \u25a0 \u25a0 \u25a0 \u25a0  Sally\'s S...
# 434  ***** Sentinel 4: Dark Star is now available! ...
# 438  "The most complete defense and real-time strat...
# 439  Decked Builder is the premium deck building ap...
# 441  * Check in to Hotel Dash Deluxe for action, mi...
# 449  "Play the best Strategy game ever!\nStratego\x...
# 451  Over 10 million downloads! We have been workin...
# 463  Make a reservation for Hotel Dash: Suite Succe...
# 475  "Version 3.6 is now live featuring a brand new...
# 482  "Due to scarce resource, the cruel robots plan...
# 495  Euchre HD is a great partnership Euchre card g...
# 500  Ever wanted to be a hacker? Play Hack RUN! Hac...
# 545  Steering, speeding up, braking, cutting, block...
# 564  @ GAME OF THE WEEK! @\n\nThe best game on the ...
# 576  Decked Builder iPad is the iPad version of the...
# 589  GemCraft, the online sensation played over 90 ...
# 592  NUTSHELL: a revolutionary arcade-looking strat...
# 636  GLWG is the hit 3D turn-based strategy game th...
# 637  "Update News: new winter track & challenges, c...
# 641  "Every game Bobby Fischer ever played - at you...
# 644  "Forbidden Island is honestly one of the best ...
# 645  "Every game Garry Kasparov ever played - at yo...
# 652  "Garry Kasparov is widely regarded as the grea...
# 673  Discover Ticket To Ride, the digital adaptatio...
# 676  Assault Commander Ultimate is a traditional tu...
# 688  "The Original, The Best!"\n\nThe popular Arabi...
# 703  Klaverjassen is one of the most popular card g...
# 738  Let\'s be the savior of the Fortune world.\n\n...
#
#                                          Developer Age Rating  \
# 26                          Subatomic Studios, LLC         9+
# 59                                   Glu Games Inc         4+
# 70                                 "Sean O'Connor"         9+
# 91                       Blitwise Productions, LLC         9+
# 102                                 Dennis Mengelt         4+
# 106                                Limbic Software         9+
# 126                            Team17 Software Ltd        12+
# 128                                medienwerkstatt         4+
# 132                                           BLUE        12+
# 153                                       Jimmy Hu         4+
# 167                                      Savy Soda         4+
# 180                                            USM         4+
# 219                                     subzero.eu         9+
# 247                            Team17 Software Ltd        12+
# 254                                 Absolutist Ltd         4+
# 257                          UNBALANCE Corporation         4+
# 268                                Greyhound Games         9+
# 269                            Team17 Software Ltd        12+
# 270                                Asmodee Digital         9+
# 300                                    Eric Snider         4+
# 303                          UNBALANCE Corporation         4+
# 309                                Limbic Software         9+
# 318                                       Jimmy Hu         4+
# 323                   Sandstorm Interactive S.R.L.        12+
# 327                               erdenkriecher.de         4+
# 333                                   Keno Tap LLC        12+
# 343                                  Kieffer Bros.         4+
# 358  Spooky House Studios UG (haftungsbeschraenkt)         4+
# 380                                     HandyGames        12+
# 401                                            USM         4+
# 408                                   Portal Games         9+
# 421                                          Fluik         9+
# 431                                Games Cafe Inc.         4+
# 434                                        Origin8         9+
# 438                                       BLUE GNC        12+
# 439                                        TJ Soft         9+
# 441                                  Glu Games Inc         4+
# 449                       Youda Games Holding B.V.         4+
# 451                           Navigation-Info Kft.         4+
# 463                                  Glu Games Inc         4+
# 475                                     Ninja Kiwi         4+
# 482                                Crazy Carpenter         9+
# 495                         Five Lakes Studio, LLC         4+
# 500                                      i273, LLC        12+
# 545                         Hans-Juergen Richstein         4+
# 564                  Image & Form International AB         9+
# 576                                        TJ Soft         9+
# 589                              NTT Resonant Inc.         9+
# 592                             metaConsciousGames        12+
# 636                                        Rubicon        12+
# 637                                     Ninja Kiwi         4+
# 641                                        Adrian3         4+
# 644                         Button Mash Games Inc.         9+
# 645                                        Adrian3         4+
# 652                                        Adrian3         4+
# 673                                Asmodee Digital         4+
# 676                          VTDev Informatics LLC        12+
# 688                                    Isaac Daoud         4+
# 703                                     Robin Knip         4+
# 738                            Dotomchi Games Inc.         9+
#
#                                           Languages         Size  \
# 26                                               EN   75041792.0
# 59                                               EN   55803904.0
# 70                                               EN   59016192.0
# 91                                               EN   39997440.0
# 102                                              EN  259371008.0
# 106                                          EN, DE   56048640.0
# 126                                              EN  253834240.0
# 128                                      EN, FR, DE   83070976.0
# 132                                              EN   13216994.0
# 153                                              EN   21422080.0
# 167                  ZH, EN, FR, IT, JA, KO, PT, RU   49016832.0
# 180                          NL, EN, FR, DE, PT, ES  888494080.0
# 219                              EN, FR, DE, JA, ZH   56263680.0
# 247                                              EN  529755136.0
# 254                                              EN   10806272.0
# 257                                          EN, JA   23948288.0
# 268                                              EN   12067083.0
# 269                                              EN  157129465.0
# 270                          NL, EN, FR, DE, JA, ES  257059840.0
# 300                                              EN   39673856.0
# 303                                          EN, JA   23407616.0
# 309                                              EN   65495040.0
# 318                                              EN   48809984.0
# 323                                  EN, FR, IT, ES  208099328.0
# 327                                              EN  129360896.0
# 333                                              EN    5702656.0
# 343                                              EN   63946752.0
# 358                                              EN   93254656.0
# 380                  EN, FR, DE, IT, PT, RU, ES, TR   50094080.0
# 401                          NL, EN, FR, DE, PT, ES  812956672.0
# 408                                              EN  594029568.0
# 421                                              EN   63327232.0
# 431                              EN, FR, DE, IT, ES  252247040.0
# 434                                              EN  113908373.0
# 438                                              EN   42482779.0
# 439                                              EN   37890048.0
# 441                                              EN   50085888.0
# 449                                              EN  191513600.0
# 451                                              EN   32022528.0
# 463                                              EN   40382464.0
# 475                                              EN   24138752.0
# 482                                              EN   44702166.0
# 495                                              EN   35151872.0
# 500                                          EN, DE   50769920.0
# 545                                          EN, DE   50941952.0
# 564                                              EN   62007296.0
# 576                                              EN   40597504.0
# 589                          EN, FR, DE, HU, JA, ES   19544803.0
# 592                                              EN    8273920.0
# 636                                              EN   38559147.0
# 637                                              EN  164235264.0
# 641                                          EN, DE   40583168.0
# 644  EN, FR, DE, EL, HU, ID, JA, MS, PT, ZH, ES, ZH  141209600.0
# 645                                          EN, DE   39432192.0
# 652                                          EN, DE   39604224.0
# 673                              EN, FR, DE, IT, ES  668668928.0
# 676              EN, FR, DE, IT, JA, KO, PL, RU, ES   61392896.0
# 688                                              EN   45342720.0
# 703                                              EN   82276352.0
# 738                                          EN, KO   84831232.0
#
#      Primary Genre                                        Genres  \
# 26           Games        Games, Entertainment, Action, Strategy
# 59           Games        Games, Strategy, Action, Entertainment
# 70           Games                        Games, Board, Strategy
# 91           Games        Games, Family, Strategy, Entertainment
# 102          Games        Games, Strategy, Entertainment, Puzzle
# 106          Games                       Games, Strategy, Puzzle
# 126          Games        Games, Action, Entertainment, Strategy
# 128          Games            Games, Puzzle, Strategy, Education
# 132          Games                 Games, Role Playing, Strategy
# 153          Games         Games, Board, Entertainment, Strategy
# 167          Games              Games, Board, Business, Strategy
# 180          Games         Games, Board, Strategy, Entertainment
# 219          Games        Games, Strategy, Entertainment, Casual
# 247          Games        Games, Entertainment, Action, Strategy
# 254          Games        Games, Strategy, Entertainment, Puzzle
# 257          Games         Games, Strategy, Board, Entertainment
# 268          Games        Games, Action, Strategy, Entertainment
# 269          Games        Games, Entertainment, Strategy, Action
# 270          Games         Games, Strategy, Board, Entertainment
# 300          Games          Games, Card, Entertainment, Strategy
# 303          Games         Games, Strategy, Board, Entertainment
# 309          Games                       Games, Action, Strategy
# 318          Games         Games, Board, Entertainment, Strategy
# 323          Games         Games, Board, Strategy, Entertainment
# 327          Games        Games, Puzzle, Entertainment, Strategy
# 333          Games        Games, Casino, Entertainment, Strategy
# 343          Games        Games, Entertainment, Strategy, Puzzle
# 358          Games        Games, Entertainment, Puzzle, Strategy
# 380          Games        Games, Entertainment, Strategy, Action
# 401          Games         Games, Board, Strategy, Entertainment
# 408          Games         Games, Board, Strategy, Entertainment
# 421          Games    Games, Simulation, Entertainment, Strategy
# 431          Games        Games, Entertainment, Action, Strategy
# 434          Games        Games, Action, Strategy, Entertainment
# 438          Games                       Games, Casual, Strategy
# 439          Games          Games, Entertainment, Card, Strategy
# 441          Games        Games, Entertainment, Action, Strategy
# 449          Games         Games, Entertainment, Board, Strategy
# 451          Games                       Games, Strategy, Puzzle
# 463          Games        Games, Entertainment, Strategy, Action
# 475          Games                       Games, Strategy, Casual
# 482          Games                       Games, Strategy, Action
# 495          Games          Games, Entertainment, Card, Strategy
# 500          Games        Games, Puzzle, Entertainment, Strategy
# 545          Games        Games, Strategy, Entertainment, Racing
# 564          Games                       Games, Strategy, Action
# 576          Games          Games, Strategy, Entertainment, Card
# 589          Games                       Games, Strategy, Action
# 592          Games                       Games, Strategy, Puzzle
# 636          Games  Games, Role Playing, Entertainment, Strategy
# 637          Games                       Games, Strategy, Casual
# 641          Games         Games, Strategy, Board, Entertainment
# 644          Games                        Games, Strategy, Board
# 645          Games         Games, Entertainment, Board, Strategy
# 652          Games         Games, Strategy, Entertainment, Board
# 673          Games         Games, Board, Entertainment, Strategy
# 676          Games                        Games, Board, Strategy
# 688          Games          Games, Strategy, Entertainment, Card
# 703  Entertainment          Entertainment, Games, Strategy, Card
# 738          Games  Games, Entertainment, Strategy, Role Playing
#
#     Original Release Date Current Version Release Date
# 26              5/10/2008                   11/04/2018
# 59             28/01/2009                    2/07/2014
# 70             27/02/2009                   30/05/2019
# 91             15/04/2009                   31/08/2016
# 102             6/05/2009                    4/12/2017
# 106            24/05/2009                    5/03/2018
# 126            12/07/2009                    9/12/2016
# 128            11/07/2009                    8/04/2019
# 132            25/07/2009                   15/10/2012
# 153             1/09/2009                   16/01/2018
# 167            28/09/2009                   17/11/2015
# 180            25/10/2009                   11/01/2019
# 219            11/08/2011                   23/10/2017
# 247            27/10/2010                   27/01/2017
# 254            25/02/2010                   28/11/2017
# 257             4/03/2010                    2/08/2018
# 268             5/04/2010                   26/08/2010
# 269             1/04/2010                   27/08/2012
# 270             1/04/2010                    6/07/2017
# 300            15/04/2010                   16/09/2017
# 303            23/04/2010                   27/01/2017
# 309            23/05/2010                    3/03/2018
# 318            18/05/2010                   16/01/2018
# 323            22/05/2010                   10/06/2019
# 327            28/05/2010                    2/03/2019
# 333             7/06/2010                   14/03/2019
# 343            29/06/2010                    3/04/2019
# 358            11/07/2010                   20/10/2017
# 380            12/08/2010                   14/09/2017
# 401            29/09/2010                   18/06/2018
# 408            17/09/2010                   30/10/2017
# 421            15/10/2010                   24/04/2018
# 431            18/11/2010                   11/09/2017
# 434            26/11/2010                   19/12/2012
# 438            16/10/2010                   15/10/2012
# 439            14/10/2010                    8/06/2018
# 441            28/10/2010                   12/08/2014
# 449            28/10/2010                   13/05/2019
# 451            27/10/2010                   29/10/2014
# 463             2/12/2010                   18/12/2013
# 475             7/12/2010                    4/08/2017
# 482             4/12/2010                    6/08/2012
# 495            10/02/2011                   18/08/2014
# 500             7/04/2011                   29/11/2018
# 545            16/03/2011                    9/10/2014
# 564             6/10/2011                    3/09/2017
# 576             4/02/2011                   11/06/2018
# 589            15/04/2011                   16/08/2011
# 592             6/03/2011                   27/05/2017
# 636            26/03/2011                   10/02/2012
# 637             1/04/2011                   21/10/2016
# 641            29/03/2011                    3/07/2014
# 644             9/11/2011                   19/04/2018
# 645            15/04/2011                    3/07/2014
# 652             4/04/2011                    3/07/2014
# 673            18/05/2011                    9/05/2019
# 676             4/05/2011                   20/03/2017
# 688             5/05/2011                   17/09/2016
# 703            22/05/2011                   11/06/2019
# 738             1/07/2011                   26/07/2018

# %%
data["Genres"].unique()
# Out:
# array(['Games, Entertainment, Action, Strategy',
#        'Games, Strategy, Action, Entertainment', 'Games, Board, Strategy',
#        'Games, Family, Strategy, Entertainment',
#        'Games, Strategy, Entertainment, Puzzle',
#        'Games, Strategy, Puzzle',
#        'Games, Action, Entertainment, Strategy',
#        'Games, Puzzle, Strategy, Education',
#        'Games, Role Playing, Strategy',
#        'Games, Board, Entertainment, Strategy',
#        'Games, Board, Business, Strategy',
#        'Games, Board, Strategy, Entertainment',
#        'Games, Strategy, Entertainment, Casual',
#        'Games, Strategy, Board, Entertainment',
#        'Games, Action, Strategy, Entertainment',
#        'Games, Entertainment, Strategy, Action',
#        'Games, Card, Entertainment, Strategy', 'Games, Action, Strategy',
#        'Games, Puzzle, Entertainment, Strategy',
#        'Games, Casino, Entertainment, Strategy',
#        'Games, Entertainment, Strategy, Puzzle',
#        'Games, Entertainment, Puzzle, Strategy',
#        'Games, Simulation, Entertainment, Strategy',
#        'Games, Casual, Strategy', 'Games, Entertainment, Card, Strategy',
#        'Games, Entertainment, Board, Strategy', 'Games, Strategy, Casual',
#        'Games, Strategy, Action',
#        'Games, Strategy, Entertainment, Racing',
#        'Games, Strategy, Entertainment, Card',
#        'Games, Role Playing, Entertainment, Strategy',
#        'Games, Strategy, Board', 'Games, Strategy, Entertainment, Board',
#        'Entertainment, Games, Strategy, Card',
#        'Games, Entertainment, Strategy, Role Playing',
#        'Games, Role Playing, Strategy, Reference',
#        'Games, Strategy, Role Playing',
#        'Games, Role Playing, Strategy, Entertainment',
#        'Games, Puzzle, Strategy',
#        'Games, Strategy, Entertainment, Action',
#        'Games, Entertainment, Adventure, Strategy',
#        'Games, Strategy, Casual, Entertainment',
#        'Games, Strategy, Role Playing, Entertainment',
#        'Games, Strategy, Entertainment, Adventure',
#        'Games, Entertainment, Role Playing, Strategy',
#        'Games, Simulation, Strategy', 'Games, Strategy, Music, Action',
#        'Games, Strategy, Entertainment, Simulation',
#        'Productivity, Simulation, Games, Strategy',
#        'Entertainment, Strategy, Games, Puzzle',
#        'Games, Strategy, Sports, Entertainment',
#        'Games, Strategy, Entertainment, Role Playing',
#        'Games, Simulation, Strategy, Entertainment',
#        'Games, Strategy, Reference, Role Playing',
#        'Games, Strategy, Simulation',
#        'Games, Strategy, Word, Entertainment',
#        'Games, Adventure, Strategy, Utilities', 'Games, Strategy',
#        'Entertainment, Games, Puzzle, Strategy',
#        'Games, Strategy, Puzzle, Entertainment',
#        'Games, Strategy, Simulation, Entertainment',
#        'Games, Education, Role Playing, Strategy',
#        'Games, Entertainment, Strategy, Simulation',
#        'Games, Adventure, Strategy',
#        'Games, Puzzle, Strategy, Entertainment',
#        'Games, Entertainment, Strategy, Adventure',
#        'Games, Adventure, Entertainment, Strategy',
#        'Finance, Simulation, Strategy, Games',
#        'Games, Board, Strategy, Reference',
#        'Sports, Games, Strategy, Sports',
#        'Games, Strategy, Card, Entertainment',
#        'Games, Simulation, Travel, Strategy',
#        'Entertainment, Action, Games, Strategy',
#        'Games, Strategy, Simulation, Education',
#        'Games, Entertainment, Casual, Strategy',
#        'Business, Strategy, Games',
#        'Productivity, Strategy, Role Playing, Games',
#        'Games, Strategy, Medical, Role Playing',
#        'Games, Strategy, Board, Utilities',
#        'Games, Entertainment, Simulation, Strategy',
#        'Games, Reference, Board, Strategy', 'Games, Strategy, Adventure',
#        'Games, Sports, Entertainment, Strategy',
#        'Games, Simulation, Strategy, Education', 'Games, Strategy, Card',
#        'Entertainment, Board, Games, Strategy',
#        'Reference, Strategy, Games, Simulation', 'Games, Card, Strategy',
#        'Health & Fitness, Strategy, Games, Family',
#        'Games, Strategy, Education', 'Sports, Strategy, Board, Games',
#        'Reference, Games, Strategy',
#        'Games, Strategy, Social Networking, Action',
#        'Games, Racing, Strategy', 'Games, Entertainment, Strategy, Board',
#        'Productivity, Racing, Strategy, Games',
#        'Reference, Adventure, Games, Strategy',
#        'Games, Education, Simulation, Strategy',
#        'Games, Social Networking, Strategy, Card',
#        'Productivity, Board, Strategy, Games',
#        'Games, Strategy, Puzzle, Lifestyle',
#        'Games, Entertainment, Strategy, Family',
#        'Games, Social Networking, Role Playing, Strategy',
#        'Games, Card, Strategy, Entertainment'], dtype=object)

# %%
len(data["Genres"].unique())
# Out:
# 104
