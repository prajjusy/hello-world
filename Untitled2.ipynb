# %%
import pandas as pd

read = pd.read_csv("https://raw.githubusercontent.com/covid19india/api/gh-pages/csv/latest/raw_data.csv")

# %%
read.tail(60)
# Out:
#        Patient Number State Patient Number Date Announced  \
# 28123             NaN                  NaN     24/04/2020
# 28124             NaN                  NaN     24/04/2020
# 28125             NaN                  NaN     22/04/2020
# 28126             NaN                  NaN     22/04/2020
# 28127             NaN                  NaN     23/04/2020
# 28128             NaN                  NaN     23/04/2020
# 28129             NaN                  NaN     26/04/2020
# 28130             NaN                  NaN     26/04/2020
# 28131             NaN                  NaN     20/04/2020
# 28132             NaN                  NaN     20/04/2020
# 28133             NaN                  NaN     21/04/2020
# 28134             NaN                  NaN     21/04/2020
# 28135             NaN                  NaN     21/04/2020
# 28136             NaN                  NaN     21/04/2020
# 28137             NaN                  NaN     23/04/2020
# ...
